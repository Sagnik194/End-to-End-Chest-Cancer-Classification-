# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\sagnik sen\\Desktop\\End-to-End-Chest-Cancer-Classification-\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\sagnik sen\\Desktop\\End-to-End-Chest-Cancer-Classification-'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import sys
sys.path.append("src")

# %%
from cnnClassifier.entity.config_entity import DataIngestionConfig

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    
     
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    
    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-05-07 16:31:22,707: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-05-07 16:31:22,714: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-05-07 16:31:22,718: INFO: common: created directory at: artifacts]
# [2026-05-07 16:31:22,724: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-05-07 16:31:22,726: INFO: 586056171: Downloading data from https://drive.google.com/file/d/1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m/view?usp=sharing into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?id=1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m
# From (redirected): https://drive.google.com/uc?id=1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m&confirm=t&uuid=330b64a1-699a-486b-a09f-103f2f33ae02
# To: c:\Users\sagnik sen\Desktop\End-to-End-Chest-Cancer-Classification-\artifacts\data_ingestion\data.zip
# 100%|██████████| 49.0M/49.0M [01:37<00:00, 500kB/s]
# [2026-05-07 16:33:04,429: INFO: 586056171: Downloaded data from https://drive.google.com/file/d/1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m/view?usp=sharing into file artifacts/data_ingestion/data.zip]

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\sagnik sen\Desktop\End-to-End-Chest-Cancer-Classification-\research

# %%
import os
print(os.path.exists("config/config.yaml"))
# Out:
# False

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\sagnik sen\Desktop\End-to-End-Chest-Cancer-Classification-\research

# %%
import os
print(os.listdir(".."))
# Out:
# ['cv projects', 'desktop.ini', 'Docker Desktop.lnk', 'End-to-End-Chest-Cancer-Classification-', 'End-to-End-Chest-Cancer-Classification-using-MLflow-DVC-main', 'laptop-price-predictor', 'machine-learning-projects', 'Microsoft Edge.lnk', 'Minor II plan.docx', 'mnc coding.pdf', 'MongoDB Compass.lnk', 'mysql-connector-j-9.6.0', 'new resume.pdf', 'np.txt', 'Payment Status.pdf', 'SAYANI PAL_RESUME (1).docx']

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\sagnik sen\Desktop\End-to-End-Chest-Cancer-Classification-

# %%
from pathlib import Path

print(Path("config/config.yaml").exists())
print(Path("params.yaml").exists())
# Out:
# True
# True

# %%
try:
    config = ConfigurationManager()

    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(config=data_ingestion_config)

    data_ingestion.download_file()

    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 13
#       9
#      10     data_ingestion.extract_zip_file()
#      11
#      12 except Exception as e:
# ---> 13     raise e
#
# Cell In[26], line 13
#       9
#      10     data_ingestion.extract_zip_file()
#      11
#      12 except Exception as e:
# ---> 13     raise e
#
# Cell In[12], line 7, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       3         self,
#       4         config_filepath = CONFIG_FILE_PATH,
#       5         params_filepath = PARAMS_FILE_PATH):
#       6
# ----> 7         self.config = read_yaml(config_filepath)
#       8         self.params = read_yaml(params_filepath)
#       9
#      10         create_directories([self.config.artifacts_root])
#
# File <@beartype(cnnClassifier.utils.common.read_yaml) at 0x23347f139c0>:33, in read_yaml(__beartype_object_2419179810064, __beartype_get_violation, __beartype_conf, __beartype_object_2419258933824, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~\Desktop\End-to-End-Chest-Cancer-Classification-\src\cnnClassifier\utils\common.py:36, in read_yaml(path_to_yaml)
#      34     raise ValueError("yaml file is empty")
#      35 except Exception as e:
# ---> 36     raise e
#
# File ~\Desktop\End-to-End-Chest-Cancer-Classification-\src\cnnClassifier\utils\common.py:29, in read_yaml(path_to_yaml)
#      16 """reads yaml file and returns
#      17
#      18 Args:
#    (...)     26     ConfigBox: ConfigBox type
#      27 """
#      28 try:
# ---> 29     with open(path_to_yaml) as yaml_file:
#      30         content = yaml.safe_load(yaml_file)
#      31         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\config\\config.yaml'
