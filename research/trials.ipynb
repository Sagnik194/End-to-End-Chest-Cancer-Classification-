# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from beartype import beartype

# %%
@beartype
def get_product(x: int, y: int):
    return x * y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
import gdown

# %%
url = "https://drive.google.com/drive/folders/1QUWQmb_SbXgqTGp87ah0fcaLnrty26F-?usp=sharing"

# %%
url = "https://drive.google.com/file/d/1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m/view?usp=sharing"

# %%
url = "https://drive.google.com/drive/folders/1QUWQmb_SbXgqTGp87ah0fcaLnrty26F-?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m
# From (redirected): https://drive.google.com/uc?id=1vvlleeRzg6sYCFvMKYy5-Y25MIb30P-m&confirm=t&uuid=9d9e3cb7-1c97-419f-b943-0ceb0af4bdfb
# To: c:\Users\sagnik sen\Desktop\End-to-End-Chest-Cancer-Classification-\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:10<00:00, 4.48MB/s]
# 'Chest-CT-Scan-data.zip'

# %%
import gdown
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import gdown
#
# ModuleNotFoundError: No module named 'gdown'

# %%
from ensure import ensure_annotations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from ensure import ensure_annotations
#
# File c:\Users\sagnik sen\.conda\envs\cancer\Lib\site-packages\ensure\__init__.py:4
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#       3 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
# ----> 4 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_raises_regex, ensure_annotations
#
# File c:\Users\sagnik sen\.conda\envs\cancer\Lib\site-packages\ensure\main.py:922
#     919 check = Check()
#     921 ensure_raises = unittest_case.assertRaises
# --> 922 ensure_raises_regex = unittest_case.assertRaisesRegexp
#
# AttributeError: 'TestCase' object has no attribute 'assertRaisesRegexp'
